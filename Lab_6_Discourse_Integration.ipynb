# %% [markdown]
# <a href="https://colab.research.google.com/github/Smarikatripathi/NLP/blob/main/Lab_6_Discourse_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
# Example text
text = """
John went to the store. He bought some milk. Then, he went home.
"""

# %%
# Process the text with spaCy
doc = nlp(text)

# %%
# Function to resolve pronouns to their antecedents
def resolve_pronouns(doc):
    resolved_text = []
    last_subject = None

    for sent in doc.sents:
        sent_resolved = []
        for token in sent:
            if token.pos_ == 'PRON' and last_subject:
                sent_resolved.append(last_subject.text)
            else:
                if token.dep_ == 'nsubj':
                    last_subject = token
                sent_resolved.append(token.text)
        resolved_text.append(' '.join(sent_resolved))

    return ' '.join(resolved_text)

# %%
# Get the resolved text
resolved_text = resolve_pronouns(doc)

print("Original text:")
print(text)
print("\nResolved text:")
print(resolved_text)
# Out:
# Original text:
#
# John went to the store. He bought some milk. Then, he went home.
#
#
# Resolved text:
#
#  John went to the store . John bought some milk . Then , John went home .
