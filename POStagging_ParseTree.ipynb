# %% [markdown]
# <a href="https://colab.research.google.com/github/Smarikatripathi/NLP/blob/main/POStagging_ParseTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# %%
sentence = input("Enter a sentence: ")
# Out:
# Enter a sentence: My name is Smarika Tripathi

# %%
# Process the sentence with spaCy
doc = nlp(sentence)

# Print tokens and their part-of-speech tags
print("Tokenization and Part-of-Speech Tagging:")
for token in doc:
    print(f"Token: {token.text}, POS Tag: {token.pos_}")
# Out:
# Tokenization and Part-of-Speech Tagging:
# Token: My, POS Tag: PRON
# Token: name, POS Tag: NOUN
# Token: is, POS Tag: AUX
# Token: Smarika, POS Tag: PROPN
# Token: Tripathi, POS Tag: PROPN

# %%
from spacy import displacy
# Generate the dependency parse tree
parse_tree = displacy.parse_deps(doc)

# %%
# Generate the dependency parse tree
options = {'compact': True, 'bg': '#ffffff',
           'color': 'black', 'font': 'Source Sans Pro'}
#parse_tree = displacy.render(doc, style='dep', options=options)
parse_tree = displacy.render(doc, style='dep', options=options, jupyter=False)


# Save the SVG to a file
output_path = "parse_tree.svg"
with open(output_path, "w", encoding="utf-8") as f:
  f.write(parse_tree)

print(f"Parse tree saved to '{output_path}'")
# Out:
# Parse tree saved to 'parse_tree.svg'

# %%
from IPython.display import SVG, display

# Display the saved SVG file inline
display(SVG("parse_tree.svg"))

# %%
print("Smarika tripathi_41_b0ce")
# Out:
# Smarika tripathi_41_b0ce
