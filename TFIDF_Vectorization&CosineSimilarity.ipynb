# %% [markdown]
# <a href="https://colab.research.google.com/github/Smarikatripathi/NLP/blob/main/TFIDF_Vectorization%26CosineSimilarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Example documents
doc1 = "My name is Smarika Tripathi."
doc2 = "I am a Computer Engineering student."

# %%
# List of documents
documents = [doc1, doc2]

# %%
# Initialize TF-IDF Vectorizer
vectorizer = TfidfVectorizer()

# %%
# Fit the vectorizer to documents and transform the documents
tfidf_vectors = vectorizer.fit_transform(documents)

# %%
# Print the vocabulary (terms)
print("Vocabulary (terms):")
print(vectorizer.get_feature_names_out())
# Out:
# Vocabulary (terms):
# ['am' 'computer' 'engineering' 'is' 'my' 'name' 'smarika' 'student'
#  'tripathi']

# %%
# Print TF-IDF vectors for each document
print("\nTF-IDF Vectors:")
for i, doc in enumerate(documents):
    print(f"Document {i + 1}:")
    print(tfidf_vectors[i])
    print()
# Out:
# TF-IDF Vectors:
# Document 1:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5 stored elements and shape (1, 9)>
#   Coords	Values
#   (0, 4)	0.447213595499958
#   (0, 5)	0.447213595499958
#   (0, 3)	0.447213595499958
#   (0, 6)	0.447213595499958
#   (0, 8)	0.447213595499958
#
# Document 2:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 4 stored elements and shape (1, 9)>
#   Coords	Values
#   (0, 0)	0.5
#   (0, 1)	0.5
#   (0, 2)	0.5
#   (0, 7)	0.5

# %%
#import cosine_similarity
from sklearn.metrics.pairwise import cosine_similarity

# Calculate cosine similarity between the documents
cosine_sim = cosine_similarity(tfidf_vectors[0], tfidf_vectors[1]).flatten()[0]

# Print cosine similarity
print(f"Cosine Similarity between document 1 and document 2: {cosine_sim}")
# Out:
# Cosine Similarity between document 1 and document 2: 0.0
